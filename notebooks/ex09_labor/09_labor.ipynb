# %% [markdown]
# # Bài 9 - Lao động AI
#
# Notebook này chạy script `src/optimization/ex9_labor_ai.py` và đọc kết quả trong `results/`.

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
subprocess.run([sys.executable, 'src/optimization/ex9_labor_ai.py'], cwd=ROOT, check=True)

# %%
import pandas as pd
from pathlib import Path
results = Path.cwd() / 'results'
if not results.exists():
    results = Path.cwd().parent / 'results'
sorted(p.name for p in results.glob('ex*.csv'))[:20]
