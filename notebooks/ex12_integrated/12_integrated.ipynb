# %% [markdown]
# # Bài 12 - AIDEOM-VN tích hợp
#
# Notebook này chạy script `src/dashboard/ex12_integrated_aideom.py` và đọc kết quả trong `results/`.

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
subprocess.run([sys.executable, 'src/dashboard/ex12_integrated_aideom.py'], cwd=ROOT, check=True)

# %%
import pandas as pd
from pathlib import Path
results = Path.cwd() / 'results'
if not results.exists():
    results = Path.cwd().parent / 'results'
sorted(p.name for p in results.glob('ex*.csv'))[:20]
