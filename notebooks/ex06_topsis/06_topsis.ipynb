# %% [markdown]
# # Bài 6 - TOPSIS
#
# Notebook này chạy script `src/mcdm/ex6_topsis_regions.py` và đọc kết quả trong `results/`.

# %%
from pathlib import Path
import subprocess, sys
ROOT = Path.cwd()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
subprocess.run([sys.executable, 'src/mcdm/ex6_topsis_regions.py'], cwd=ROOT, check=True)

# %%
import pandas as pd
from pathlib import Path
results = Path.cwd() / 'results'
if not results.exists():
    results = Path.cwd().parent / 'results'
sorted(p.name for p in results.glob('ex*.csv'))[:20]
